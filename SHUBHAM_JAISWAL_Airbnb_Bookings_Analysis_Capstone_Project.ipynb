# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamjaiswal123/airbnb-booking-analysis/blob/main/SHUBHAM_JAISWAL_Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Airbnb?**
#
# Airbnb, as in “Air Bed and Breakfast,” is a service that lets property owners rent out their spaces to travelers looking for a place to stay. Travelers can rent a space for multiple people to share, a shared space with private rooms, or the entire property for themselves.
#
# Airbnb was started in 2008 by Brian Chesky and Joe Gebbia, two industrial designers that recently moved to San Francisco. Unable to afford the rent for their loft at the time, the pair decided to make up the money they needed by renting out their apartment to people who couldn’t find hotels to stay at while attending nearby trade shows. They set up air mattresses in the apartment’s living room for their guests to sleep on and cooked homemade breakfast in the morning. Since then, Airbnb has become one of the trailblazers of peer-to-peer property rental.

# %% [markdown]
# # <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/CAPSTONE PROJECT/Airbnb NYC 2019.csv'

# %% [markdown]
# Importing Dataset From Drive

# %%
df =pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
pd.notnull(df['reviews_per_month'])
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Name: reviews_per_month, Length: 48895, dtype: bool

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# From the above observation, we can see that our dataset contains 48895 data and 16 columns. Now, let's take a look about the columns.
#
#
#
# *   id : a unique id identifying an airbnb listing
# *   name: It is representing the accomodation.
# *   host_id: It is an unique id representing an airbnb host.
# *   host_name : It is a name under which host is registered.
# *   neighbourhood_group : It is a group of area.
# *   latitude : It is one of the coordinate of airbnb listing.
# *   longitude : It is one of the coordinate of airbnb listing.
# *   room_type : It categorize the rooms which comes under listing.
# *   price : It represents the price of listing.
# *   minimum_nights : The minimum nights required to stay by a visitor in a    single visit.
# *   number_of_reviews : Count of total reviews given by visitors.
# *   last_review : Date of Last Review.
# *   reviews_per_month : Rate of reviews given by visitors per month.
# *   calculated_host_listing_count : Number of listings registered under one host.
# *   availability_365 : A host availability for number of days throughout the year.

# %%
df.fillna(0, inplace=True)
#If a listing has never recieved a review, it is possible and valid. So, we will use fillna(0) to fill those values.

# %% [markdown]
# Lattitude, longitude are coordinates and id & host_id are unique id. So, we are going to exclude them as shown below:

# %%
excluded_columns = set(df.columns) - {'latitude', 'longitude', 'id', 'host_id'}
df[excluded_columns].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.000000    48895.000000       48895.000000       48895.000000
# mean     152.720687        7.029962          23.274466           1.090910
# std      240.154170       20.510550          44.550582           1.597283
# min        0.000000        1.000000           0.000000           0.000000
# 25%       69.000000        1.000000           1.000000           0.040000
# 50%      106.000000        3.000000           5.000000           0.370000
# 75%      175.000000        5.000000          24.000000           1.580000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# ...

# %%
distinct_column_list = df[excluded_columns].describe().columns.tolist()

# %%
plt.figure(figsize=(10,6))
heatmap = sns.heatmap(df[distinct_column_list].corr(), linewidths=0, vmin=-1, annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Taking Necessary Columns Only

# %%
new_df = df[['id','name','host_id','host_name','neighbourhood_group','neighbourhood','room_type','price','minimum_nights','number_of_reviews','calculated_host_listings_count','availability_365' ]]
new_df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood        room_type  \
# 0         John            Brooklyn          Kensington     Private room
# 1     Jennifer           Manhattan             Midtown  Entire home/apt
# ...

# %% [markdown]
# **1. What can we learn about different hosts and areas?**

# %%
hosts_areas = new_df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()
hosts_areas.sort_values(by='calculated_host_listings_count',ascending=False).head(10)
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13221  Sonder (NYC)           Manhattan                             327
# 1838     Blueground           Manhattan                             230
# 9746        Michael           Manhattan                             212
# 3254          David           Manhattan                             202
# 9745        Michael            Brooklyn                             159
# 6812           John           Manhattan                             151
# 3253          David            Brooklyn                             142
# 7279           Kara           Manhattan                             135
# 9860           Mike           Manhattan                             134
# 436            Alex           Manhattan                             134

# %% [markdown]
# From the above data, we observe that most number of listings are from **Manhattan** created Sonder(NYC), Blueground, Michael, David.

# %% [markdown]
# **2. What can be learn from predictions?(ex: locations, prices, reviews,etc)**

# %%
areas_reviews = new_df.groupby(['name','neighbourhood_group','price','minimum_nights'])['number_of_reviews'].count().reset_index()
price_reviews1 = areas_reviews.sort_values(by='price',ascending=False).head(100)
price_reviews1
# Out:
#                                                     name neighbourhood_group  \
# 27239    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 1128                                 1-BR Lincoln Center           Manhattan
# 20235                Furnished room in Astoria apartment              Queens
# 41061                                 Spanish Harlem Apt           Manhattan
# 2240   2br - The Heart of NYC: Manhattans Lower East ...           Manhattan
# ...                                                  ...                 ...
# 34669  Private bedroom, Queenbed on suite bath and cl...           Manhattan
# 37296                 Room with sofa bed or air mattress              Queens
# 34692                  Private cozy Bedroom in Brooklyn             Brooklyn
# 48264                                   wait until later              Queens
# 6977                 Beautiful upper west side townhouse           Manhattan
#
# ...

# %%
area = price_reviews1['neighbourhood_group']
price = price_reviews1['price']

fig = plt.figure(figsize = (10,5))

#Creating a bar plot
plt.bar(area, price, color='grey', width=0.4)
plt.xlabel("area")
plt.ylabel("price")
plt.title("price vs area")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ef86139a00e> in <module>()
# ----> 1 area = price_reviews1['neighbourhood_group']
#       2 price = price_reviews1['price']
#       3
#       4 fig = plt.figure(figsize = (10,5))
#       5
#
# NameError: name 'price_reviews1' is not defined

# %%
price_reviews = areas_reviews.sort_values(by='number_of_reviews',ascending=False).head(100)
price_reviews
# Out:
#                                                     name neighbourhood_group  \
# 22538                                     Hillside Hotel              Queens
# 26262                   Loft Suite @ The Box House Hotel            Brooklyn
# 4635          Artsy Private BR in Fort Greene Cumberland            Brooklyn
# 22539                                     Hillside Hotel              Queens
# 23587  IN MINT CONDITION-STUDIOS EAST 44TH/UNITED NAT...           Manhattan
# ...                                                  ...                 ...
# 32504  Perfect NYC neighborhood! 15 min. to Central P...           Manhattan
# 32500                          Perfect NYC Flat! Modern!           Manhattan
# 32503         Perfect NYC crib for Explorers & Travelers           Manhattan
# 32553                     Perfect Upper West Side Studio           Manhattan
# 32495                     Perfect Luxury Studio in DUMBO            Brooklyn
#
# ...

# %%
area = price_reviews['neighbourhood_group']
price = price_reviews['price']

flg = plt.figure(figsize =(10,5))

#Creating a bar chart
plt.bar(area,price,color='blue',width=0.4)
plt.xlabel("area")
plt.ylabel("price")
plt.title("Price vs Number of reviews")
plt.show()

# %% [markdown]
# From the above analysis, we observe that majority of people prefer to stay in place where price is less.

# %% [markdown]
# **3. Which hosts are the busiest and why?**

# %%
busiest_hosts = new_df.groupby(['host_name','neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='minimum_nights',ascending=False).head(5)
busiest_hosts
# Out:
#           host_name neighbourhood_group        room_type  minimum_nights
# 16555  Sonder (NYC)           Manhattan  Entire home/apt             319
# 2301     Blueground           Manhattan  Entire home/apt             230
# 12305       Michael           Manhattan  Entire home/apt             143
# 9196           Kara           Manhattan  Entire home/apt             129
# 4134          David           Manhattan  Entire home/apt             117

# %%
name = busiest_hosts['host_name']
stayed = busiest_hosts['minimum_nights']

fig = plt.figure(figsize = (10,5))

#Creating the bar plot.
plt.bar(name, stayed, color='maroon', width=0.4)

plt.xlabel("Name of the Host")
plt.ylabel("Minimum number of nights stayed")
plt.title("Busiest Hosts")
plt.show()

# %% [markdown]
# **From the above observations, Busiest Hosts are as follows:**
# 1. Sonder(NYC)
# 2. Blueground
# 3. Michael
# 4. Kara
# 5. David

# %% [markdown]
# **4. Is there any noticeable difference of traffic among different areas and what could be the reason for it?**

# %%
traffic_areas = new_df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_areas = traffic_areas.sort_values(by='minimum_nights',ascending=False)
traffic_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
room_type = traffic_areas['room_type']
stayed = traffic_areas['minimum_nights']

fig = plt.figure(figsize =(10,5))

#creating the bar plot
plt.bar(room_type, stayed, color='GREEN', width=0.4)
plt.xlabel("Room type")
plt.ylabel("Minimum numbers of nights stayed")
plt.title("Traffic Areas")
plt.show()

# %% [markdown]
# **BIVARIATE ANALYSIS**
#
#
# Longitude vs Latitude (representing different neighbourhood groups)

# %%
f, ax = plt.subplots(figsize=(18,10))
ax = sns.scatterplot(y=df.latitude, x=df.longitude,hue=df.neighbourhood_group,palette="coolwarm")
plt.show()

# %% [markdown]
# Longitude vs Latitude (representing availability of rooms)

# %%
f, ax = plt.subplots(figsize=(18,10))
ax = sns.scatterplot(y=df.latitude,x=df.longitude,hue=df.availability_365,palette="coolwarm")
plt.show()

# %% [markdown]
# **Conclusion**
#
# So, we can conclude from the above dataset that it is rich in data but there is lack of features. From the above analysis, we can conclude that:
#
# *   Majority of visitors do not prefer shared rooms, they tend to visit private room or entire home.
# *   Manhattan and Brooklyn are the two distinguished, expensive and posh areas of NY.
# *   Although location of property is highly related with its price, but a property in popular location doesn't mean it will stay occupied most of the time.
# *   Features given in this dataset aren't good enough in deciding the property valuation, which led to high error rate while performing a regression. We can observe this by corelation heatmap. If features like bedrooms, washrooms, age of property, tax-rate applicable on land, extra amenities provided in room, distance to nearest hospitals, stores, etc. These features will tell us more accurately about the price prediction.
# *   Higher the number of reviews for a particular neigbourhood group, higher the people there which ultimately means that, place is a tourist place.
# *   People mostly prefer Entire room/apartment room type for their stay and renting out and they spent more nights there compared to other room types.
